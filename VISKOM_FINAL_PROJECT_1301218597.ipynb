# %% [markdown]
# <a href="https://colab.research.google.com/github/nurhilalhamdi/viskom_project/blob/main/VISKOM_FINAL_PROJECT_1301218597.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FINAL PROJECT
# # 1301218597 - Nurhilal Hamdi
#
# IMAGE CLASSIFICATION USING SQUEEZENET
#
# REVIEW PAPER | AlexNet-level accuracy with 50x fewer parameters and <0.5MB model size
# --- | ---
#
#
# https://paperswithcode.com/paper/squeezenet-alexnet-level-accuracy-with-50x

# %%
import pandas as pd
import numpy as np
import os, sys
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import cv2
from keras.datasets import cifar10
from keras.utils import to_categorical
import json
from sklearn.model_selection import train_test_split 
from PIL import Image
# import SqueezeNet

from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras import layers, datasets, models, losses, optimizers, metrics, utils, callbacks
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image as tf_ppimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMGPATH = 'CIFAR10'
CLASSES = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
LBL = dict(zip(range(10), CLASSES))
IN_SHAPE = (32, 32, 3)

# %%
print(LBL)
# Out:
# {0: 'plane', 1: 'car', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'}

# %%
# NEEDS CIFAR FOLDER ON WORKING DIR

def load_CIFAR_batch(filename):
    """ load single batch of cifar """
    with open(filename, 'rb') as f:
        datadict = pickle.load(f, encoding='latin1')
        X = datadict['data']
        Y = datadict['labels']
#         X = X.reshape(10000,3072)
        Y = np.array(Y)
        return X, Y

def load_CIFAR10(ROOT):
    """ load all of cifar """
    xs = []
    ys = []
    for b in range(1,6):
        f = os.path.join(ROOT, f'data_batch_{b}')
        X, Y = load_CIFAR_batch(f)
        xs.append(X)
        ys.append(Y)
    Xtr = np.concatenate(xs)
    Ytr = np.concatenate(ys)
    del X, Y
    Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
    return Xtr, Ytr, Xte, Yte

def get_CIFAR10_data(num_training=45000, num_validation=5000, num_test=10000):
    # Load the raw CIFAR-10 data
    cifar10_dir = os.path.join(os.getcwd(), 'CIFAR10')
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    x_train = X_train.astype('float32')
    x_test = X_test.astype('float32')

    x_train /= 255
    x_test /= 255    

    # Subsample the data
    mask = range(num_training, int(num_training) + int(num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_test, y_test, X_val, y_val

# Onehot 10 classes encoding
# y_train_onehot = utils.to_categorical(y_train, num_classes=10)
# y_val_onehot = utils.to_categorical(y_val, num_classes=10)
# y_test_onehot = utils.to_categorical(y_test, num_classes=10)

# %%
# load train and test dataset
def load_dataset():
    # load dataset
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    # one hot encode target values
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    trainX, testX = prep_pixels(trainX, testX)
    return trainX, trainY, testX, testY
 
# scale pixels
def prep_pixels(train, test):
    # convert from integers to floats
    train_norm = train.astype('float32')
    test_norm = test.astype('float32')
    # normalize to range 0-1
    train_norm = train_norm / 255.0
    test_norm = test_norm / 255.0
    # return normalized images
    return train_norm, test_norm

# %%
X_train, y_train, X_test, y_test = load_dataset()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
print('Train - Test - Val: images shape:')
print(*list(zip(('x_train', 'y_train', 'x_test', 'y_test'), 
                map(lambda x: x.shape, (X_train, y_train, X_test, y_test)))), sep='\n')
# Out:
# Train - Test - Val: images shape:
# ('x_train', (50000, 32, 32, 3))
# ('y_train', (50000, 10))
# ('x_test', (10000, 32, 32, 3))
# ('y_test', (10000, 10))

# %%
def plot_images(images, labels):        
    # FOR CIFAR batches: 
    # inorder to view in imshow we need image of type (height, width, channel) rather than (channel, height, width)
    #     IMG = []
    #     for img in images:
    #         img_reshape = np.reshape(img,(3,32,32)) # get the first element from list
    #         IMG.append(np.transpose(img_reshape/255., (1,2,0)))
    #  plt.xlabel(CLASSES[y+x])
    fig = plt.figure(figsize=(8, 8))
    # plot image grid
    for x in range(5):
        label = labels[x].argmax()
        for y in range(1):
            ax = fig.add_subplot(5, 5, 5*y+x+1)
            plt.imshow(images[y+x])
            plt.xticks(np.array([]))
            plt.yticks(np.array([]))
            plt.xlabel(LBL[label])
    plt.show()

# %%
# Visualize CIFAR-10
print('Training images : ' + str(X_train.shape[0]) + ' images.')
plot_images(X_train[:5], y_train[:5])
print(20 * '-')
print('Testing images : ' + str(X_test.shape[0]) + ' images.')
plot_images(X_test[:5], y_test[:5])
# Out:
# Training images : 50000 images.
# --------------------
# Testing images : 10000 images.

# %%
def fire_module(x, fire_id, squeeze=16, expand=64):
    sq1x1 = "squeeze1x1"
    exp1x1 = "expand1x1"
    exp3x3 = "expand3x3"
    relu = "relu_"
    s_id = 'fire' + str(fire_id) + '/'

    channel_axis = 3

    x = layers.Convolution2D(squeeze, (1, 1), padding='valid', name=s_id + sq1x1)(x)
    x = layers.Activation('relu', name=s_id + relu + sq1x1)(x)

    left = layers.Convolution2D(expand, (1, 1), padding='valid', name=s_id + exp1x1)(x)
    left = layers.Activation('relu', name=s_id + relu + exp1x1)(left)

    right = layers.Convolution2D(expand, (3, 3), padding='same', name=s_id + exp3x3)(x)
    right = layers.Activation('relu', name=s_id + relu + exp3x3)(right)

    x = layers.concatenate([left, right], axis=channel_axis, name=s_id + 'concat')
    return x

# %%
def SqueezeNet(input_shape=IN_SHAPE, classes=10):

    img_input = layers.Input(shape=input_shape)

    x = layers.Convolution2D(64, (3, 3), strides=(2, 2), padding='valid', name='conv1')(img_input)
    x = layers.Activation('relu', name='relu_conv1')(x)
    x = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1')(x)

    x = fire_module(x, fire_id=2, squeeze=16, expand=64)
    x = fire_module(x, fire_id=3, squeeze=16, expand=64)
    x = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3')(x)

    x = fire_module(x, fire_id=4, squeeze=32, expand=128)
    x = fire_module(x, fire_id=5, squeeze=32, expand=128)
#     x = layers.Dropout(0.2, name='drop9')(x)
    x = layers.BatchNormalization()(x)

    x = layers.Convolution2D(classes, (1, 1), padding='valid', name='conv10')(x)
    x = layers.Activation('relu', name='relu_conv10')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.1, name='drop11')(x)

    out = layers.Activation('softmax', name='loss')(x) 
    model = models.Model(img_input, out, name='squeezenet')

    return model

# %%
def compile_model(model):
    opt = optimizers.Adam(lr=0.0001)#, momentum=0.9)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['accuracy'])
    return model

# %%
sn = SqueezeNet()
sn = compile_model(sn)
sn.summary()
len(sn.layers)
# Out:
# Model: "squeezenet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1 (Conv2D)                 (None, 15, 15, 64)   1792        ['input_1[0][0]']
#
#  relu_conv1 (Activation)        (None, 15, 15, 64)   0           ['conv1[0][0]']
#
#  pool1 (MaxPooling2D)           (None, 7, 7, 64)     0           ['relu_conv1[0][0]']
#
#  fire2/squeeze1x1 (Conv2D)      (None, 7, 7, 16)     1040        ['pool1[0][0]']
#
#  fire2/relu_squeeze1x1 (Activat  (None, 7, 7, 16)    0           ['fire2/squeeze1x1[0][0]']
#  ion)
#
#  fire2/expand1x1 (Conv2D)       (None, 7, 7, 64)     1088        ['fire2/relu_squeeze1x1[0][0]']
#
#  fire2/expand3x3 (Conv2D)       (None, 7, 7, 64)     9280        ['fire2/relu_squeeze1x1[0][0]']
#
#  fire2/relu_expand1x1 (Activati  (None, 7, 7, 64)    0           ['fire2/expand1x1[0][0]']
#  on)
#
#  fire2/relu_expand3x3 (Activati  (None, 7, 7, 64)    0           ['fire2/expand3x3[0][0]']
#  on)
#
#  fire2/concat (Concatenate)     (None, 7, 7, 128)    0           ['fire2/relu_expand1x1[0][0]',
#                                                                   'fire2/relu_expand3x3[0][0]']
#
#  fire3/squeeze1x1 (Conv2D)      (None, 7, 7, 16)     2064        ['fire2/concat[0][0]']
#
#  fire3/relu_squeeze1x1 (Activat  (None, 7, 7, 16)    0           ['fire3/squeeze1x1[0][0]']
#  ion)
#
#  fire3/expand1x1 (Conv2D)       (None, 7, 7, 64)     1088        ['fire3/relu_squeeze1x1[0][0]']
#
#  fire3/expand3x3 (Conv2D)       (None, 7, 7, 64)     9280        ['fire3/relu_squeeze1x1[0][0]']
#
#  fire3/relu_expand1x1 (Activati  (None, 7, 7, 64)    0           ['fire3/expand1x1[0][0]']
#  on)
#
#  fire3/relu_expand3x3 (Activati  (None, 7, 7, 64)    0           ['fire3/expand3x3[0][0]']
#  on)
#
#  fire3/concat (Concatenate)     (None, 7, 7, 128)    0           ['fire3/relu_expand1x1[0][0]',
#                                                                   'fire3/relu_expand3x3[0][0]']
#
#  pool3 (MaxPooling2D)           (None, 3, 3, 128)    0           ['fire3/concat[0][0]']
#
#  fire4/squeeze1x1 (Conv2D)      (None, 3, 3, 32)     4128        ['pool3[0][0]']
#
#  fire4/relu_squeeze1x1 (Activat  (None, 3, 3, 32)    0           ['fire4/squeeze1x1[0][0]']
#  ion)
#
#  fire4/expand1x1 (Conv2D)       (None, 3, 3, 128)    4224        ['fire4/relu_squeeze1x1[0][0]']
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#
#  fire4/expand3x3 (Conv2D)       (None, 3, 3, 128)    36992       ['fire4/relu_squeeze1x1[0][0]']
#
#  fire4/relu_expand1x1 (Activati  (None, 3, 3, 128)   0           ['fire4/expand1x1[0][0]']
#  on)
#
#  fire4/relu_expand3x3 (Activati  (None, 3, 3, 128)   0           ['fire4/expand3x3[0][0]']
#  on)
#
#  fire4/concat (Concatenate)     (None, 3, 3, 256)    0           ['fire4/relu_expand1x1[0][0]',
#                                                                   'fire4/relu_expand3x3[0][0]']
#
#  fire5/squeeze1x1 (Conv2D)      (None, 3, 3, 32)     8224        ['fire4/concat[0][0]']
#
#  fire5/relu_squeeze1x1 (Activat  (None, 3, 3, 32)    0           ['fire5/squeeze1x1[0][0]']
#  ion)
#
#  fire5/expand1x1 (Conv2D)       (None, 3, 3, 128)    4224        ['fire5/relu_squeeze1x1[0][0]']
#
#  fire5/expand3x3 (Conv2D)       (None, 3, 3, 128)    36992       ['fire5/relu_squeeze1x1[0][0]']
#
#  fire5/relu_expand1x1 (Activati  (None, 3, 3, 128)   0           ['fire5/expand1x1[0][0]']
#  on)
#
#  fire5/relu_expand3x3 (Activati  (None, 3, 3, 128)   0           ['fire5/expand3x3[0][0]']
#  on)
#
#  fire5/concat (Concatenate)     (None, 3, 3, 256)    0           ['fire5/relu_expand1x1[0][0]',
#                                                                   'fire5/relu_expand3x3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 3, 3, 256)   1024        ['fire5/concat[0][0]']
#  alization)
#
#  conv10 (Conv2D)                (None, 3, 3, 10)     2570        ['batch_normalization[0][0]']
#
#  relu_conv10 (Activation)       (None, 3, 3, 10)     0           ['conv10[0][0]']
#
#  global_average_pooling2d (Glob  (None, 10)          0           ['relu_conv10[0][0]']
#  alAveragePooling2D)
#
#  batch_normalization_1 (BatchNo  (None, 10)          40          ['global_average_pooling2d[0][0]'
#  rmalization)                                                    ]
#
#  drop11 (Dropout)               (None, 10)           0           ['batch_normalization_1[0][0]']
#
#  loss (Activation)              (None, 10)           0           ['drop11[0][0]']
#
# ==================================================================================================
# Total params: 124,050
# Trainable params: 123,518
# Non-trainable params: 532
# __________________________________________________________________________________________________
# 40

# %%
def run_test_harness(model, X_train, y_train, X_test, y_test):
    """
    function takes model X,Y train test arguments and create data generator for fit and evaluate.
    return summarize diagnostics.
    """
#     datagen = tf_ppimg.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, validation_split=0.2, horizontal_flip=True)
#     # prepare iterator
#     it_train = datagen.flow(X_train, y_train, batch_size=64)

    batch_size = 64
    # Generator for train and validation data
    datagen = tf_ppimg.ImageDataGenerator(validation_split=0.2,
                                          width_shift_range=0.1, 
                                          height_shift_range=0.1,
                                          shear_range=0.2,
                                          zoom_range=0.2,
                                          horizontal_flip=True)
    
    train_generator = datagen.flow(x=X_train,    
                                   y=y_train,  
                                   batch_size=batch_size,
                                   seed=39,
                                   shuffle=True,
                                   subset='training')
    
    val_generator = datagen.flow(X_train, 
                                 y_train,
                                 seed=39,
                                 shuffle=True,
                                 batch_size=batch_size,
                                 subset='validation')

    # test datagen
    test_datagen = tf_ppimg.ImageDataGenerator(rescale=1./255)
    
    # fit model
    steps = train_generator.n//batch_size
    history = model.fit(train_generator, 
                        steps_per_epoch=steps, 
                        epochs=400, 
                        validation_data=val_generator,
                        validation_steps=val_generator.n//batch_size)
    # evaluate model
    _, acc = model.evaluate(X_test, y_test, verbose=0)
    print('> %.3f' % (acc * 100.0))

    return history

# %%
# entry point, run the test harness
history = run_test_harness(sn, X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/400
# 625/625 [==============================] - 29s 46ms/step - loss: 1.7219 - accuracy: 0.3915 - val_loss: 1.6949 - val_accuracy: 0.3902
# Epoch 2/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.6108 - accuracy: 0.4353 - val_loss: 1.7610 - val_accuracy: 0.3551
# Epoch 3/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.5494 - accuracy: 0.4643 - val_loss: 1.5688 - val_accuracy: 0.4550
# Epoch 4/400
# 625/625 [==============================] - 29s 46ms/step - loss: 1.5068 - accuracy: 0.4810 - val_loss: 1.4940 - val_accuracy: 0.4778
# Epoch 5/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.4723 - accuracy: 0.4916 - val_loss: 1.6069 - val_accuracy: 0.4247
# Epoch 6/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.4515 - accuracy: 0.4959 - val_loss: 1.4831 - val_accuracy: 0.4828
# Epoch 7/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.4311 - accuracy: 0.5062 - val_loss: 1.4674 - val_accuracy: 0.4879
# Epoch 8/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.4008 - accuracy: 0.5155 - val_loss: 1.4549 - val_accuracy: 0.4896
# Epoch 9/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.3804 - accuracy: 0.5249 - val_loss: 1.2770 - val_accuracy: 0.5576
# Epoch 10/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.3667 - accuracy: 0.5287 - val_loss: 1.3184 - val_accuracy: 0.5419
# Epoch 11/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.3434 - accuracy: 0.5379 - val_loss: 1.3425 - val_accuracy: 0.5208
# Epoch 12/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.3295 - accuracy: 0.5424 - val_loss: 1.3185 - val_accuracy: 0.5463
# Epoch 13/400
# 625/625 [==============================] - 29s 46ms/step - loss: 1.3074 - accuracy: 0.5477 - val_loss: 1.3726 - val_accuracy: 0.5106
# Epoch 14/400
# 625/625 [==============================] - 34s 54ms/step - loss: 1.3023 - accuracy: 0.5505 - val_loss: 1.2565 - val_accuracy: 0.5633
# Epoch 15/400
# 625/625 [==============================] - 29s 46ms/step - loss: 1.2871 - accuracy: 0.5585 - val_loss: 1.4321 - val_accuracy: 0.5079
# Epoch 16/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.2723 - accuracy: 0.5648 - val_loss: 1.2378 - val_accuracy: 0.5677
# Epoch 17/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.2526 - accuracy: 0.5708 - val_loss: 1.2121 - val_accuracy: 0.5721
# Epoch 18/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.2484 - accuracy: 0.5697 - val_loss: 1.2382 - val_accuracy: 0.5767
# Epoch 19/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.2328 - accuracy: 0.5774 - val_loss: 1.2131 - val_accuracy: 0.5845
# Epoch 20/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.2209 - accuracy: 0.5803 - val_loss: 1.5030 - val_accuracy: 0.4708
# Epoch 21/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.2195 - accuracy: 0.5776 - val_loss: 1.2576 - val_accuracy: 0.5712
# Epoch 22/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.2017 - accuracy: 0.5838 - val_loss: 1.1237 - val_accuracy: 0.6145
# Epoch 23/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.2011 - accuracy: 0.5856 - val_loss: 1.5028 - val_accuracy: 0.4717
# Epoch 24/400
# 625/625 [==============================] - 29s 46ms/step - loss: 1.1872 - accuracy: 0.5903 - val_loss: 1.1727 - val_accuracy: 0.5972
# Epoch 25/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.1704 - accuracy: 0.5988 - val_loss: 1.0739 - val_accuracy: 0.6403
# Epoch 26/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.1686 - accuracy: 0.5997 - val_loss: 1.2157 - val_accuracy: 0.5691
# Epoch 27/400
# 625/625 [==============================] - 34s 54ms/step - loss: 1.1558 - accuracy: 0.6018 - val_loss: 1.0830 - val_accuracy: 0.6254
# Epoch 28/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.1446 - accuracy: 0.6066 - val_loss: 1.0926 - val_accuracy: 0.6240
# Epoch 29/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.1444 - accuracy: 0.6054 - val_loss: 1.2280 - val_accuracy: 0.5774
# Epoch 30/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.1364 - accuracy: 0.6087 - val_loss: 1.1286 - val_accuracy: 0.6202
# Epoch 31/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.1251 - accuracy: 0.6126 - val_loss: 1.2091 - val_accuracy: 0.5837
# Epoch 32/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.1198 - accuracy: 0.6140 - val_loss: 1.0796 - val_accuracy: 0.6280
# Epoch 33/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.1034 - accuracy: 0.6193 - val_loss: 1.1125 - val_accuracy: 0.6157
# Epoch 34/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.0985 - accuracy: 0.6204 - val_loss: 1.0408 - val_accuracy: 0.6382
# Epoch 35/400
# 625/625 [==============================] - 28s 46ms/step - loss: 1.1002 - accuracy: 0.6198 - val_loss: 1.1060 - val_accuracy: 0.6154
# Epoch 36/400
# 625/625 [==============================] - 29s 46ms/step - loss: 1.0900 - accuracy: 0.6242 - val_loss: 1.0813 - val_accuracy: 0.6302
# Epoch 37/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.0878 - accuracy: 0.6237 - val_loss: 1.0097 - val_accuracy: 0.6530
# Epoch 38/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.0792 - accuracy: 0.6278 - val_loss: 0.9418 - val_accuracy: 0.6753
# Epoch 39/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.0691 - accuracy: 0.6285 - val_loss: 1.0044 - val_accuracy: 0.6538
# Epoch 40/400
# 625/625 [==============================] - 29s 47ms/step - loss: 1.0625 - accuracy: 0.6322 - val_loss: 1.0918 - val_accuracy: 0.6218
# Epoch 41/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.0546 - accuracy: 0.6347 - val_loss: 1.0006 - val_accuracy: 0.6572
# Epoch 42/400
# 625/625 [==============================] - 28s 45ms/step - loss: 1.
400
# 625/625 [==============================] - 30s 48ms/step - loss: 0.5918 - accuracy: 0.7909 - val_loss: 0.6664 - val_accuracy: 0.7767
# Epoch 400/400
# 625/625 [==============================] - 30s 48ms/step - loss: 0.5895 - accuracy: 0.7912 - val_loss: 0.6361 - val_accuracy: 0.7865
# > 80.160

# %%
save = input('Do you want to save last run (y/n) ?')
if save == 'y':
    model_json = sn.to_json()
    with open('saves//squeeze_net_model2.json', 'w') as f:
        f.write(model_json)

    with open('saves//history_model2.json', 'w') as f:
        json.dump(history.history, f)

    # save model's learned weights
    sn.save('saves//model2.h5', overwrite=True)
    
load = input('Do you want to load best model (y/n) ? ')
if load == 'y':
    sn = load_model(os.path.join(os.getcwd(), 'saves//model2.h5'))
    history = json.load(open(os.path.join(os.getcwd(), 'saves//history_model2.json')))
# Out:
# Do you want to save last run (y/n) ?y
# Do you want to load best model (y/n) ? y

# %%
evaluate = sn.evaluate(X_test, y_test)
print(f'{list(zip(evaluate, sn.metrics_names))}')
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6086 - accuracy: 0.8016
# [(0.6085888147354126, 'loss'), (0.8015999794006348, 'accuracy')]

# %%
def plot_accuracy_and_loss(history):
    "function reads model's history and plot its train and validation - acc and loss over the run"
    plt.figure(1, figsize= (15, 10))
    # plot train and test accuracy
    plt.subplot(221)
    plt.plot(history['accuracy'])
    plt.plot(history['val_accuracy'])
    plt.title('SqueezeNet accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    # plot train and test loss
    plt.subplot(222)
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('SqueezeNet loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show();   
    # save plot to file
    filename = sys.argv[0].split('/')[-1]
    plt.savefig(filename + '_plot.png')
    plt.close()

# %%
plot_accuracy_and_loss(history)

# %%
y_pred = sn.predict(X_test)
y_pred_classes = [np.argmax(el) for el in y_pred]
preds=np.argmax(y_pred, axis=1)
tests=np.argmax(y_test, axis=1)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %%
cr = classification_report(tests, preds)
print(f'Classification Report:\n {cr}')
cm = tf.math.confusion_matrix(labels=tests, predictions=preds, num_classes=10)
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1000
#            1       0.85      0.93      0.89      1000
#            2       0.76      0.73      0.75      1000
#            3       0.73      0.57      0.64      1000
#            4       0.79      0.77      0.78      1000
#            5       0.83      0.60      0.70      1000
#            6       0.69      0.93      0.79      1000
#            7       0.79      0.90      0.84      1000
#            8       0.90      0.88      0.89      1000
#            9       0.88      0.85      0.86      1000
#
#     accuracy                           0.80     10000
#    macro avg       0.80      0.80      0.80     10000
# weighted avg       0.80      0.80      0.80     10000
# Text(33.0, 0.5, 'True')

# %%
# {0: 'plane',
#  1: 'car',
#  2: 'bird',
#  3: 'cat',
#  4: 'deer',
#  5: 'dog',
#  6: 'frog',
#  7: 'horse',
#  8: 'ship',
#  9: 'truck'}

# %%
def predict_label(model, labels, imagepath):

    img = tf.keras.preprocessing.image.load_img(os.path.join(imagepath), target_size=(32, 32))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, 0)      # Create batch axis (32, 32, 3) => (1, 32, 32, 3)

    predictions = model.predict(img_array)[0]
    index = np.argmax(predictions)
    result = labels[index]
    imge = plt.imread(imagepath)
    plt.figure(figsize=(5, 5))
    plt.imshow(imge)
    plt.title(f'prediction: {result}')
    plt.xticks([])
    plt.yticks([])
    plt.show();
    return result

# %%
# Checks new images from google image
for fig in range(1,3):
    path = os.path.join(os.getcwd(), f'/content/uploads/{fig}.jpg')
    predict_label(sn, LBL, path)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
